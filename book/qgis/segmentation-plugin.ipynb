# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/GeoAI-Book/blob/main/book/qgis/segmentation-plugin.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/GeoAI-Book/main?urlpath=lab/tree/book/qgis/segmentation-plugin.ipynb)

# %% [markdown]
# # Training and Inference in QGIS
#
# ## Introduction
#
# ## Learning Objectives
#
# ## Semantic Segmentation Panel
#
# ### Creating Training Data
#
# ### Training a Model
#
# ### Running Inference
#
# ## Instance Segmentation Panel
#
# ## DeepForest Panel
#
# ### Loading Pretrained Models
#
# ### Running Predictions
#
# ### Exporting Results
#
# ## Water Segmentation Panel
#
# ## Key Takeaways
#
# ## Exercises
#
# ### Exercise 1: End-to-End Semantic Segmentation of Buildings
#
# ### Exercise 2: Comparing Segmentation Architectures
#
# ### Exercise 3: Tree Crown Detection with DeepForest
#
# ### Exercise 4: Water Body Mapping with OmniWaterMask
#
# ### Exercise 5: Instance Segmentation versus Semantic Segmentation
